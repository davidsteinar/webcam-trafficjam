# %%
import tensorflow as tf
import pprint
import pycurl
from io import BytesIO
import json
import os
import time
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /home/hudz0r/miniconda3/envs/tensorflow/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### Load model from file

# %%
sess = tf.Session()
# we want the variable values from from my_tf_model
saver = tf.train.import_meta_graph('models/my_tf_model.meta')
saver.restore(sess, tf.train.latest_checkpoint('models'))

graph = tf.get_default_graph()

# init variables from trained model

W_conv1 = graph.get_collection('trainable_variables')[10]

b_conv1 = graph.get_collection('trainable_variables')[11]
W_conv2 = graph.get_collection('trainable_variables')[12]
b_conv2 = graph.get_collection('trainable_variables')[13]
W_conv3 = graph.get_collection('trainable_variables')[14]
b_conv3 = graph.get_collection('trainable_variables')[15]
W_dense1 = graph.get_collection('trainable_variables')[16]
b_dense1 = graph.get_collection('trainable_variables')[17]
W_out = graph.get_collection('trainable_variables')[18]
b_out = graph.get_collection('trainable_variables')[19]

# build graph

X = tf.placeholder(tf.float32, [1,112, 200, 3])

pkeep = tf.placeholder(tf.float32)

def build_conv_net(X_in, keep_prob, dropout=0.1610, kernel_size=3, filters=32, hiddenunits=500):
        
    
    conv1 = tf.nn.relu(tf.nn.conv2d(X_in, W_conv1, strides=[1,1,1,1], padding="VALID") + b_conv1)
         
    maxpool1 = tf.layers.max_pooling2d(inputs=conv1,
                                       pool_size=2,
                                       strides=2)
            
    conv2 = tf.nn.relu(tf.nn.conv2d(maxpool1, W_conv2, strides=[1,1,1,1], padding="VALID") + b_conv2)
        
    maxpool2 = tf.layers.max_pooling2d(inputs=conv2,
                                       pool_size=2,
                                       strides=2)
        
    conv3 = tf.nn.relu(tf.nn.conv2d(maxpool2, W_conv3, strides=[1,1,1,1], padding="VALID") + b_conv3)
        
    maxpool3 = tf.layers.max_pooling2d(inputs=conv3,
                                       pool_size=2,
                                       strides=2)
                
    flat = tf.contrib.layers.flatten(inputs=maxpool3)
                
    dropout1 = tf.layers.dropout(flat, rate=pkeep, training=False)
        
    dense1 = tf.nn.relu(tf.matmul(dropout1, W_dense1) + b_dense1)
        
    dropout2 = tf.layers.dropout(dense1, rate=pkeep, training=False)
        
    out = tf.nn.relu(tf.matmul(dropout2, W_out) + b_out)
    
    return out
# Out:
# INFO:tensorflow:Restoring parameters from models/my_tf_model
# <tf.Variable 'conv2d_3/kernel:0' shape=(3, 3, 3, 32) dtype=float32_ref>
# <tf.Variable 'conv2d_3/bias:0' shape=(32,) dtype=float32_ref>
# <tf.Variable 'conv2d_4/kernel:0' shape=(3, 3, 32, 32) dtype=float32_ref>
# <tf.Variable 'conv2d_4/bias:0' shape=(32,) dtype=float32_ref>
# <tf.Variable 'conv2d_5/kernel:0' shape=(3, 3, 32, 32) dtype=float32_ref>
# <tf.Variable 'conv2d_5/bias:0' shape=(32,) dtype=float32_ref>
# <tf.Variable 'dense_2/kernel:0' shape=(8832, 500) dtype=float32_ref>
# <tf.Variable 'dense_2/bias:0' shape=(500,) dtype=float32_ref>
# <tf.Variable 'dense_3/kernel:0' shape=(500, 1) dtype=float32_ref>
# <tf.Variable 'dense_3/bias:0' shape=(1,) dtype=float32_ref>

# %% [markdown]
# ### Graph info

# %%
print(graph.get_all_collection_keys())
print(graph.get_collection('trainable_variables')[8])
# Out:
# ['queue_runners', 'summaries', 'trainable_variables', 'train_op', 'variables', 'update_ops']
# <tf.Variable 'dense_1/kernel:0' shape=(500, 1) dtype=float32_ref>

# %% [markdown]
# ### Functions

# %%
# saves image to data/
def fetch_img(id):
    os.system("python3 test.py " + str(id))
    
# returns image from webcam with id
def get_img(id):
    image_raw = plt.imread("data/" + str(id) + ".jpg")
    image = np.expand_dims(image_raw, axis=0)
    return image, image_raw

def main_loop(webcam_id_list):
    for w in webcam_id_list:
        fetch_img(w)
        i, image_raw = get_img(w)
        plt.imshow(image_raw)
        plt.show()
        
        t1 = time.time()
        count = sess.run(net, feed_dict={X:i, pkeep:0.856})
        t2 = time.time()
        
        
        print("Webcam " + str(w) + " has " + str(count[0][0]) + " number of cars")
        print("time : " + str(t2-t1))

# %% [markdown]
# ### Main program

# %%
webcam_id_list = [1508414354, 1508415574, 1508413912, 1508413758, 1508413604]
sleep_time = 60 #check every minute
net = build_conv_net(X, pkeep)
while(1):
    main_loop(webcam_id_list)
    time.sleep(sleep_time)
# Out:
# Webcam 1508414354 has 37.8026 number of cars
# time : 0.14785027503967285
# Webcam 1508415574 has 51.574 number of cars
# time : 0.01772594451904297
# Webcam 1508413912 has 37.7817 number of cars
# time : 0.022864818572998047
# Webcam 1508413758 has 29.1453 number of cars
# time : 0.02282857894897461
# Webcam 1508413604 has 64.9398 number of cars
# time : 0.017833232879638672
# Webcam 1508414354 has 37.8026 number of cars
# time : 0.01779031753540039
# Webcam 1508415574 has 51.574 number of cars
# time : 0.01975083351135254
# Webcam 1508413912 has 37.7817 number of cars
# time : 0.0192563533782959
# Webcam 1508413758 has 29.1453 number of cars
# time : 0.023467063903808594
# Webcam 1508413604 has 64.9398 number of cars
# time : 0.022986173629760742
# Webcam 1508414354 has 37.8026 number of cars
# time : 0.022222518920898438
# Webcam 1508415574 has 51.574 number of cars
# time : 0.022449493408203125
# Webcam 1508413912 has 37.7817 number of cars
# time : 0.021356821060180664
# Webcam 1508413758 has 29.1453 number of cars
# time : 0.019379615783691406
# Webcam 1508413604 has 64.9398 number of cars
# time : 0.02220320701599121
